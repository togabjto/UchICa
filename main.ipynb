# %% [markdown]
# # main関数

# %%
def select_station():
    print("select_station")
    return 0

def pay():
    print("pay")
    return 0

def charge():
    print("charge")
    return 0

# %%
menu = 1
balance = 500
def main(menu):
    while(True):
        print ("menu")
        menu = int(input())
        if menu == 1:
            fare = select_station()
            if fare == 0:
                balance = pay()
            
        elif menu == 2:
            balance = pay()

        elif menu == 99:
            print("システムを終了します")
            break
        else:
            print("エラー")


main(menu)
# Out:
# menu
# select_station
# pay
# menu
# pay
# menu
# エラー
# menu
# エラー
# menu
# エラー
# menu
# エラー
# menu
# エラー
# menu
# エラー
# menu
# エラー
# menu
# システムを終了します

# %%
    try:
    num1 = int(input("1つ目の整数: "))
    num2 = int(input("2つ目の整数: "))

    if menu = 1:
        
    elif menu = 2:

    elif menu = 99:

    else

    except ValueError:
        print("エラー: 有効な整数を入力してください。")
        return
