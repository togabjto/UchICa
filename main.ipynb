# %% [markdown]
# # main関数

# %%
def select_station():
    print("select_station")
    return 0

def pay(balance , fare):
    print(f"チャージ残高は[{balance}]円です。")
    if balance < fare:
        print("残高不足です")
        while (balance < fare):
            print("3000円自動チャージします")
            balance += 3000
            print(balance)
        balance -= fare
        print(fare)# でばっく
        print(balance)# でばっく
        print(f"精算後の残高は[{balance}]円です。")
        if balance < 500:
            print("残高が500 円未満のため3000 円自動チャージします")
            balance += 3000
            print(f"チャージ残高は[{balance}]円です。")
    return balance

def charge():
    print("charge")
    return 0
pay(30,3000)
# Out:
# チャージ残高は[30]円です。
# 残高不足です
# 3000円自動チャージします
# 3030
# 3000
# 30
# 精算後の残高は[30]円です。
# 残高が500 円未満のため3000 円自動チャージします
# チャージ残高は[3030]円です。
# 3030

# %%
menu = 1
def main(menu):
    
    balance = 500
    print ("【ウチダ電鉄 交通系ICカード検証システム】\n")
    print ("1: 乗車駅選択\n2: チャージ機能\n")
    print ("使用する機能を入力してください(終了する場合には99 を入力)\n")
    while(True):
        try:
            menu = int(input())

            if menu == 1:
                fare = select_station()
                if fare == 0:
                    balance = pay()
                
            elif menu == 2:
                balance = pay()

            elif menu == 99:
                print("システムを終了します")
                break
            else:
                print("正しい数値を入力してください。 ")
        except ValueError:
            print("正しい数値を入力してください。 ")


if __name__ == "__main__":
    main(0)
# Out:
# 【ウチダ電鉄 交通系ICカード検証システム】
#
# 1: 乗車駅選択
# 2: チャージ機能
#
# 使用する機能を入力してください(終了する場合には99 を入力)
#
# 正しい数値を入力してください。
# 【ウチダ電鉄 交通系ICカード検証システム】
#
# 1: 乗車駅選択
# 2: チャージ機能
#
# 使用する機能を入力してください(終了する場合には99 を入力)
#
# 正しい数値を入力してください。
# 【ウチダ電鉄 交通系ICカード検証システム】
#
# 1: 乗車駅選択
# 2: チャージ機能
#
# 使用する機能を入力してください(終了する場合には99 を入力)
#
# システムを終了します
