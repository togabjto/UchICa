# %% [markdown]
# ■初期画面

# %%
print("【ウチダ電鉄 交通系ICカード検証システム】1: 乗車駅選択2: チャージ機能使用する機能を入力してください(終了する場合には99 を入力)")
# Out:
# 【ウチダ電鉄 交通系ICカード検証システム】1: 乗車駅選択2: チャージ機能使用する機能を入力してください(終了する場合には99 を入力)

# %% [markdown]
# # A
